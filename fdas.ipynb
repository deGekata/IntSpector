# %%
import pandas as pd
import matplotlib.pyplot as plt
import typing as tp
from matplotlib.axes import Axes
import numpy as np

arr = np.array([180, 220, 255, 260, 225, 230, int(35*(360/50))])
plt.plot([2017, 2018, 2019,2020,2021,2022,2023], arr, '-o')
